# %% [markdown]
# <a href="https://colab.research.google.com/github/szhan227/FinalProject2022FallCSCI2470/blob/main/Copy_of_Semantic_Parsing_Stencil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Pre-processing

# %%
# data from https://www.cs.utexas.edu/~ai-lab/pubs/cocktail-ecml-01.pdf
# and https://www.cs.utexas.edu/users/ml/nldata.html 

import regex as re
from nltk.stem import SnowballStemmer
from urllib.request import urlopen
from contextlib import closing
from sklearn.model_selection import train_test_split

ss = SnowballStemmer('english')

inputs = []
queries = []

with closing(urlopen('ftp://ftp.cs.utexas.edu/pub/mooney/nl-ilp-data/jobsystem/jobqueries640')) as r:
  for line in r.readlines():
    line = line.decode('utf-8')
    input, query = line.lower().split('],')

    # parse input. lowercase, stem with nltk, add <s>
    input = input[7:-2].split(',')
    input = [ss.stem(x) for x in input]
    inputs.append(input)

    # parse query 
    query = query.strip('.\n')
    # https://stackoverflow.com/questions/43092970/tokenize-by-using-regular-expressions-parenthesis
    query = re.findall(r"\w+(?:'\w+)?|[^\w\s]", query)
    query = ["<s>"] + query + ["</s>"]
    queries.append(query)

# do train test split of 500 training and 140 test instances
inputs_train, inputs_test, queries_train, queries_test = train_test_split(inputs, queries, test_size=140, random_state=8)

# %%
inputs_train
# Out:
# [['what', 'job', 'are', 'there', 'use', 'tcl/tk'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'use',
#   'c++',
#   'that',
#   'requir',
#   'a',
#   'bscs',
#   'but',
#   'desir',
#   'a',
#   'mscs'],
#  ['what', 'job', 'are', 'there', 'for', 'a', 'network', 'specialist'],
#  ['give', 'me', 'the', 'job', 'in', 'visual', 'c++'],
#  ['list', 'job', 'requir', 'bsee'],
#  ['give',
#   'me',
#   'the',
#   'job',
#   'for',
#   'a',
#   'databas',
#   'specialist',
#   'in',
#   'usa'],
#  ['what',
#   'job',
#   'can',
#   'a',
#   'delphi',
#   'develop',
#   'find',
#   'in',
#   'san',
#   'antonio',
#   'on',
#   'window'],
#  ['list', 'job', 'requir', 'ba'],
#  ['i',
#   'wonder',
#   'what',
#   'jpl',
#   'doe',
#   'on',
#   'unix',
#   'with',
#   'prolog',
#   'and',
#   'vax'],
#  ['what', 'job', 'are', 'avail', 'for', 'a', 'solari', 'system', 'administr'],
#  ['what',
#   'job',
#   'requir',
#   'a',
#   'bscs',
#   'degre',
#   'and',
#   'desir',
#   'an',
#   'mscs',
#   'degre'],
#  ['are',
#   'there',
#   'ani',
#   'comput',
#   'job',
#   'in',
#   'the',
#   'field',
#   'of',
#   'statist'],
#  ['list', 'the', 'job', 'requir', 'java', 'a', 'bscs', '2', 'year', 'experi'],
#  ['show', 'me', 'the', 'job', 'in', 'texa', 'use', 'ai', 'on', 'unix'],
#  ['what', 'job', 'use', 'cobol', 'on', 'ibm', 'machin', 'and', 'pay', '70000'],
#  ['are', 'there', 'ani', 'job', 'in', 'san', 'antonio'],
#  ['what', 'ai', 'posit', 'requir', 'onli', 'a', 'bscs'],
#  ['show', 'me', 'austin', 'job', 'desir', 'a', 'bscs'],
#  ['tell', 'me', 'job', 'for', 'a', 'mfc', 'specialist'],
#  ['what', 'job', 'are', 'there'],
#  ['show', 'job', 'for', 'a', 'data', 'wareh', 'specialist'],
#  ['list', 'the', 'job', 'in', 'databas'],
#  ['what',
#   'job',
#   'pay',
#   '60000',
#   'are',
#   'locat',
#   'in',
#   'austin',
#   'and',
#   'requir',
#   'a',
#   'degre'],
#  ['are', 'there', 'ani', 'job', 'use', 'powerbuild'],
#  ['what',
#   'job',
#   'as',
#   'a',
#   'senior',
#   'softwar',
#   'develop',
#   'are',
#   'avail',
#   'in',
#   'houston',
#   'but',
#   'not',
#   'san',
#   'antonio'],
#  ['list', 'job', 'in', 'austin'],
#  ['show',
#   'me',
#   'the',
#   'c++',
#   'job',
#   'in',
#   'nashvill',
#   'that',
#   'desir',
#   '2',
#   'year',
#   'experien'],
#  ['list', 'the', 'job', 'use', 'cobol', 'ii'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   'at',
#   'least',
#   'a',
#   'mscs',
#   'and',
#   'know',
#   'latex'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'that',
#   'requir',
#   'a',
#   'knowledg',
#   'of',
#   'linux',
#   'in',
#   'san',
#   'antonio'],
#  ['what',
#   'oracl',
#   'job',
#   'are',
#   'there',
#   'with',
#   'compaq',
#   'in',
#   'houston',
#   'use',
#   'pcs'],
#  ['what', 'are', 'all', 'the', 'job'],
#  ['show',
#   'me',
#   'manag',
#   'job',
#   'in',
#   'boston',
#   'requir',
#   'an',
#   'mba',
#   'and',
#   'the',
#   'knowledg',
#   'of',
#   'visual',
#   'basic'],
#  ['how', 'much', 'experi', 'is', 'want', 'for', 'a', 'job', 'at', 'microsoft'],
#  ['list', 'job', 'use', 'sql'],
#  ['list', 'job', 'in', 'usa'],
#  ['find', 'all', 'network', 'administr', 'job', 'in', 'austin'],
#  ['what', 'job', 'are', 'there', 'on', 'vms'],
#  ['what', 'job', 'do', 'you', 'have'],
#  ['prolog', 'ai', 'and', 'lisp', 'and', 'graphic'],
#  ['list', 'the', 'job', 'in', 'visual', 'c++'],
#  ['what', 'job', 'doe', 'lcs', 'recruit', 'for'],
#  ['is', 'anyon', 'offer', '40000', 'for', 'ai', 'work'],
#  ['show', 'the', 'job', 'use', 'lisp', 'not', 'requir', 'a', 'bs'],
#  ['show', 'me', 'web', 'develop', 'job', 'open', 'at', 'trilog'],
#  ['show', 'job', 'in', 'austin', 'that', 'requir', 'a', 'bscs'],
#  ['are', 'there', 'ada', 'job', 'outsid', 'austin'],
#  ['doe', 'appl', 'have', 'ani', 'softwar', 'engin', 'posit'],
#  ['what', 'job', 'are', 'longhorn', 'employ', 'hire', 'for'],
#  ['list', 'job', 'in', 'wan'],
#  ['what', 'job', 'are', 'there', 'on', 'ibm'],
#  ['tell', 'me', 'job', 'use', 'visual', 'basic'],
#  ['what', 'job', 'are', 'there', 'in', 'houston'],
#  ['give', 'me', 'the', 'job', 'in', 'houston'],
#  ['are', 'there', 'ani', 'autocad', 'job', 'open'],
#  ['tell', 'me', 'job', 'use', 'html'],
#  ['show',
#   'me',
#   'job',
#   'in',
#   'dalla',
#   'requir',
#   'knowledg',
#   'of',
#   'linux',
#   'and',
#   'pay',
#   'more',
#   'than',
#   '50000',
#   'a',
#   'year'],
#  ['doe', 'anyon', 'still', 'use', 'mvs'],
#  ['give', 'me', 'the', 'job', 'for', 'a', 'game', 'specialist'],
#  ['what',
#   'job',
#   'are',
#   'avail',
#   'for',
#   'someon',
#   'who',
#   'know',
#   'oracl',
#   'on',
#   'solari'],
#  ['show', 'me', 'a', 'dell', 'job', 'in', 'austin', 'requir', 'a', 'bscs'],
#  ['what', 'job', 'at', 'dell', 'requir', 'a', 'bscs'],
#  ['what', 'java', 'job', 'are', 'there', 'with', 'tivoli', 'in', 'austin'],
#  ['are', 'there', 'ani', 'job', 'use', 'cobol'],
#  ['what',
#   'project',
#   'manag',
#   'job',
#   'are',
#   'there',
#   'that',
#   'requir',
#   'experi'],
#  ['what',
#   'job',
#   'requir',
#   '10',
#   'year',
#   'of',
#   'experi',
#   'requir',
#   'a',
#   'phd',
#   'are',
#   'in',
#   'cobol',
#   'and',
#   'are',
#   'locat',
#   'in',
#   'texa'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'in',
#   'austin',
#   'that',
#   'desir',
#   '3',
#   'year',
#   'of',
#   'experi',
#   'and',
#   'use',
#   'c++'],
#  ['list',
#   'the',
#   'job',
#   'requir',
#   'java',
#   'a',
#   'bscs',
#   '2',
#   'year',
#   'experien'],
#  ['show',
#   'me',
#   'a',
#   'job',
#   'that',
#   'requir',
#   'c++',
#   'and',
#   'java',
#   'and',
#   'is',
#   'in',
#   'austin'],
#  ['what', 'job', 'are', 'there', 'with', 'a', 'salari', 'of', '40000'],
#  ['list', 'the', 'job', 'use', 'assembl'],
#  ['which', 'job', 'in', 'houston', 'offer', 'over', '50000', 'in', 'graphic'],
#  ['are', 'there', 'ani', 'job', 'requir', 'ba'],
#  ['show', 'me', 'the', 'research', 'assist', 'job', 'in', 'aust'],
#  ['what', 'job', 'are', 'there', 'use', 'visual', 'basic'],
#  ['show', 'me', 'the', 'job', 'in', 'texa', 'use', 'ai', 'on', 'unix'],
#  ['tell', 'me', 'the', 'job', 'use', 'visual', 'basic'],
#  ['are', 'there', 'ani', 'job', 'in', 'houston'],
#  ['what', 'are', 'the', 'softwar', 'engin', 'job', 'avail', 'use', 'ada'],
#  ['what',
#   'job',
#   'pay',
#   '60000',
#   'are',
#   'locat',
#   'in',
#   'austin',
#   'and',
#   'requir',
#   'a',
#   'degre'],
#  ['list', 'the', 'requir', 'experi', 'for', 'a', 'job', 'use', 'lisp'],
#  ['what',
#   'develop',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   'a',
#   'bscs',
#   'and',
#   'c++'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'that',
#   'requir',
#   '1',
#   'year',
#   'of',
#   'experi',
#   'but',
#   'desir',
#   '2',
#   'year',
#   'of',
#   'experienc'],
#  ['what', 'job', 'use', 'fortran', 'are', 'there', 'in', 'los', 'alamo'],
#  ['show', 'me', 'austin', 'job', 'requir', 'a', 'bscs'],
#  ['show',
#   'me',
#   'job',
#   'use',
#   'lisp',
#   'that',
#   'requir',
#   'a',
#   'bscs',
#   'and',
#   'desir',
#   'a',
#   'msee'],
#  ['what', 'job', 'are', 'there', 'with', 'a', 'salari', 'of', '40000'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'do',
#   'comput',
#   'graphic',
#   'on',
#   'silicon',
#   'graphic',
#   'machin'],
#  ['show', 'me', 'the', 'job', 'applic', 'for', 'ic', 'design', 'engin'],
#  ['are', 'there', 'ani', 'softwar', 'develop', 'job', 'requir', 'bs'],
#  ['list', 'the', 'job', 'use', 'cobol', 'ii'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'onli',
#   'requir',
#   'a',
#   'bscs',
#   'and',
#   'no',
#   'experi'],
#  ['are', 'there', 'ani', 'autocad', 'job', 'open'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'in',
#   'austin',
#   'that',
#   'requir',
#   '5',
#   'year',
#   'experi'],
#  ['show',
#   'all',
#   'intern',
#   'posit',
#   'in',
#   'texa',
#   'with',
#   'network',
#   'and',
#   'java'],
#  ['list', 'all', 'job', 'use', 'c++', 'and', 'java', 'in', 'california'],
#  ['what',
#   'job',
#   'requir',
#   'at',
#   'least',
#   '1',
#   'year',
#   'of',
#   'experi',
#   'in',
#   'c++'],
#  ['are',
#   'there',
#   'job',
#   'that',
#   'do',
#   'not',
#   'requir',
#   'a',
#   'degre',
#   'in',
#   'houston'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   'a',
#   'bscs',
#   'degre',
#   'and',
#   'deal',
#   'with',
#   'tcp/ip'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'use',
#   'java',
#   'that',
#   'dont',
#   'requir',
#   'a',
#   'bscs'],
#  ['list', 'job', 'use', 'java'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'requir',
#   'a',
#   'bscs',
#   'for',
#   'boe',
#   'in',
#   'seattl'],
#  ['could', 'i', 'have', 'some', 'job', 'use', 'sql', 'with', 'oracl'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   'knowledg',
#   'of',
#   'the',
#   'platform',
#   'unix'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'use',
#   'java',
#   'that',
#   'are',
#   'not',
#   'with',
#   'ibm'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'use',
#   'java',
#   'with',
#   'salari',
#   'greater',
#   'than',
#   '500'],
#  ['are', 'there', 'ani', 'job', 'requir', 'bs'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'use',
#   'java',
#   'with',
#   'salari',
#   'greater',
#   'than',
#   '50000',
#   'per',
#   'year'],
#  ['what',
#   'job',
#   'in',
#   'san',
#   'jose',
#   'offer',
#   'a',
#   'java',
#   'programm',
#   'for',
#   '40000',
#   'a',
#   'year'],
#  ['show',
#   'me',
#   'the',
#   'titl',
#   'of',
#   'the',
#   'avail',
#   'job',
#   'use',
#   'prolog',
#   'in',
#   'houston'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'for',
#   'pascal',
#   'program',
#   'who',
#   'dont',
#   'know',
#   'c++'],
#  ['show', 'job', 'requir', 'bsee'],
#  ['what', 'microsoft', 'job', 'do', 'not', 'requir', 'a', 'bscs'],
#  ['are', 'there', 'ani', 'job', 'requir', 'bs'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'concern',
#   'game',
#   'develop',
#   'on',
#   'a',
#   'playstat'],
#  ['what', 'job', 'in', 'austin', 'requir', 'no', 'experi'],
#  ['are', 'there', 'ani', 'job', 'use', 'c++', 'with', 'dell'],
#  ['what', 'job', 'are', 'there', 'in', 'austin', 'requir', 'a', 'phd'],
#  ['show',
#   'me',
#   'job',
#   'desir',
#   'a',
#   'ma',
#   'in',
#   'austin',
#   'with',
#   'microsoft'],
#  ['show', 'me', 'the', 'job', 'use', 'lisp', 'requir', 'a', 'bscs'],
#  ['are', 'there', 'ani', 'job', 'requir', 'bscs'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   '5',
#   'year',
#   'of',
#   'experi',
#   'but',
#   'desir',
#   '10',
#   'year',
#   'of',
#   'experi'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'desir',
#   'a',
#   'bscs',
#   'are',
#   'there',
#   'for',
#   'a',
#   'c++',
#   'programm'],
#  ['show', 'me', 'job', 'are', 'dell', 'requir', 'experi', 'on', 'unix'],
#  ['give', 'me', 'the', 'job', 'for', 'a', 'lan', 'specialist'],
#  ['list', 'the', 'job', 'on', 'unix'],
#  ['show', 'job', 'in', 'usa'],
#  ['what',
#   'job',
#   'is',
#   'there',
#   'for',
#   'a',
#   'bscs',
#   'with',
#   '5',
#   'year',
#   'of',
#   'experi'],
#  ['what', 'job', 'are', 'there', 'in', 'usa', 'on', 'ibm'],
#  ['show',
#   'job',
#   'for',
#   'a',
#   'shell',
#   'programm',
#   'familiar',
#   'with',
#   'the',
#   'unix',
#   'environmen'],
#  ['are', 'there', 'ani', 'project', 'manag', 'posit', 'open'],
#  ['what', 'job', 'use', 'c++', 'with', 'the', 'web', 'on', 'mac'],
#  ['show', 'me', 'programm', 'job', 'in', 'tulsa'],
#  ['give', 'some', 'job', 'in', 'dalla', 'on', 'a', 'sun', 'system'],
#  ['could', 'a', 'senior', 'consult', 'engin', 'find', 'work', 'in', 'boston'],
#  ['what', 'job', 'pay', '40000'],
#  ['are', 'there', 'ani', 'job', 'on', 'sun'],
#  ['which',
#   'system',
#   'administr',
#   'job',
#   'in',
#   'dalla',
#   'requir',
#   '2',
#   'year',
#   'experi',
#   'and',
#   'pay',
#   '50000'],
#  ['everyth'],
#  ['tell', 'me', 'job', 'requir', 'ba'],
#  ['list', 'the', 'job', 'for', 'a', 'client', 'server', 'specialist'],
#  ['i',
#   'sure',
#   'would',
#   'like',
#   'a',
#   'perl',
#   'job',
#   'at',
#   'microsoft',
#   'involv',
#   'databas'],
#  ['what', 'job', 'in', 'austin', 'or', 'dalla', 'desir', 'a', 'degre'],
#  ['show', 'me', 'the', 'job', 'with', '30000', 'salari'],
#  ['what',
#   'job',
#   'are',
#   'avail',
#   'use',
#   'apach',
#   'with',
#   'a',
#   'specialti',
#   'area',
#   'of',
#   'network'],
#  ['what',
#   'are',
#   'the',
#   'job',
#   'that',
#   'requir',
#   'experi',
#   'with',
#   'microsoft',
#   'word'],
#  ['show', 'me', 'dalla', 'job', 'requir', 'a', 'bscs'],
#  ['are', 'there', 'ani', 'job', 'in', 'san', 'antonio'],
#  ['show', 'the', 'job', 'on', 'mvs'],
#  ['list', 'job', 'requir', 'bscs', 'use', 'java'],
#  ['show', 'me', 'the', 'job', 'that', 'are', 'not', 'in', 'haskel'],
#  ['which',
#   'job',
#   'are',
#   'for',
#   'bsee',
#   'major',
#   'with',
#   'at',
#   'least',
#   '5',
#   'year',
#   'experi',
#   'in',
#   'window',
#   'nt'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'in',
#   'austin',
#   'that',
#   'requir',
#   'a',
#   'bscs',
#   'degre'],
#  ['what',
#   'are',
#   'the',
#   'job',
#   'in',
#   'washington',
#   'that',
#   'requir',
#   'at',
#   'least',
#   '5',
#   'year',
#   'of',
#   'experi'],
#  ['show', 'me', 'job', 'for', 'dell', 'requir', 'experi', 'on', 'unix'],
#  ['show', 'me', 'the', 'job', 'that', 'requir', '2', 'year', 'experien'],
#  ['what', 'job', 'are', 'there', 'on', 'x86'],
#  ['show', 'me', 'system', 'analyst', 'job', 'at', 'tivoli'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'that',
#   'requir',
#   'the',
#   'knowledg',
#   'of',
#   'linux',
#   'platform'],
#  ['is',
#   'there',
#   'anyth',
#   'for',
#   'an',
#   'old',
#   'cobol',
#   'programm',
#   'on',
#   'mvs'],
#  ['what', 'web', 'develop', 'job', 'are', 'there', 'in', 'austin'],
#  ['what', 'austin', 'area', 'web', 'job', 'requir', 'java', 'and', 'c++'],
#  ['what',
#   'are',
#   'the',
#   'job',
#   'in',
#   'washington',
#   'that',
#   'requir',
#   'at',
#   'least',
#   '5',
#   'year',
#   'of',
#   'experi'],
#  ['show', 'me', 'the', 'job', 'which', 'use', 'excel'],
#  ['tell', 'me', 'the', 'job', 'use', 'vc++'],
#  ['list', 'job', 'use', 'sql'],
#  ['what',
#   'job',
#   'in',
#   'california',
#   'requir',
#   'java',
#   'and',
#   'internet',
#   'experi'],
#  ['show',
#   'me',
#   'austin',
#   'job',
#   'requir',
#   'a',
#   'bscs',
#   'degre',
#   'with',
#   'a',
#   'salari',
#   'greater',
#   'than',
#   '50000',
#   'per',
#   'year'],
#  ['what', 'ibm', 'job', 'requir', 'use', 'java', 'on', 'commodor'],
#  ['what',
#   'are',
#   'the',
#   'job',
#   'that',
#   'requir',
#   'experi',
#   'with',
#   'aix',
#   'but',
#   'not',
#   'window',
#   'nt'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'for',
#   'peopl',
#   'in',
#   'austin',
#   'that',
#   'want',
#   'to',
#   'program',
#   'in',
#   'lisp',
#   'but',
#   'do',
#   'not',
#   'have',
#   'a',
#   'degre'],
#  ['show', 'me', 'job', 'in', 'texa'],
#  ['which',
#   'job',
#   'in',
#   'austin',
#   'offer',
#   'for',
#   'student',
#   'fresh',
#   'out',
#   'of',
#   'colleg',
#   'in',
#   'network'],
#  ['list',
#   'the',
#   'posit',
#   'that',
#   'requir',
#   'a',
#   'knowledg',
#   'of',
#   'microsoft',
#   'excel'],
#  ['show', 'me', 'all', 'job', 'that', 'are', 'avail'],
#  ['what', 'avail', 'on', 'vax', 'and', 'near', 'austin'],
#  ['tell', 'me', 'the', 'job', 'requir', 'bs', 'in', 'usa'],
#  ['what', 'are', 'the', 'degre', 'requir', 'for', 'a', 'softwar', 'engin'],
#  ['are', 'there', 'ani', 'job', 'for', 'a', 'data', 'wareh', 'specialist'],
#  ['what', 'job', 'are', 'there', 'for', 'a', 'databas', 'specialist'],
#  ['what', 'job', 'can', 'i', 'find', 'with', 'tivoli'],
#  ['what', 'job', 'are', 'there', 'for', 'programm', 'that', 'know', 'assembl'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'at',
#   'compani',
#   'in',
#   'austin',
#   'that',
#   'want',
#   'a',
#   'degre',
#   'in',
#   'bs'],
#  ['give', 'me', 'the', 'job', 'requir', 'bsee'],
#  ['what', 'softwar', 'engin', 'job', 'are', 'there', 'that', 'use', 'c++'],
#  ['what',
#   'in',
#   'dalla',
#   'that',
#   'pay',
#   'over',
#   '60000',
#   'on',
#   'linux',
#   'with',
#   'graphic',
#   'and',
#   'java'],
#  ['are', 'there', 'ani', 'unix', 'job'],
#  ['what',
#   'kind',
#   'of',
#   'job',
#   'are',
#   'avail',
#   'for',
#   'visual',
#   'basic',
#   'consult',
#   'in',
#   'boston'],
#  ['give', 'me', 'job', 'on', 'vms', 'use', 'sql'],
#  ['what',
#   'job',
#   'do',
#   'not',
#   'requir',
#   'a',
#   'degre',
#   'but',
#   'pay',
#   'more',
#   'than',
#   '60000'],
#  ['show',
#   'me',
#   'houston',
#   'job',
#   'use',
#   'c',
#   'in',
#   'the',
#   'specialti',
#   'area',
#   'of',
#   'oil',
#   'pipelin',
#   'model'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'do',
#   'comput',
#   'graphic',
#   'on',
#   'silicon',
#   'graphic',
#   'machin'],
#  ['what', 'job', 'are', 'there', 'in', 'data', 'wareh'],
#  ['which', 'job', 'pay', '60000', 'that', 'do', 'not', 'requir', 'a', 'phd'],
#  ['what', 'job', 'are', 'there', 'in', 'sql'],
#  ['show',
#   'me',
#   'the',
#   'network',
#   'job',
#   'in',
#   'houston',
#   'with',
#   'a',
#   'salari',
#   'of',
#   '50000'],
#  ['show', 'the', 'job', 'on', 'pc'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'in',
#   'texa',
#   'that',
#   'use',
#   'java',
#   'and',
#   'requir',
#   'no',
#   'experi'],
#  ['what', 'posit', 'are', 'there', 'that', 'use', 'c++', 'and', 'java'],
#  ['what', 'job', 'are', 'there', 'for', 'a', 'test', 'engin', 'use', 'java'],
#  ['list', 'job', 'on', 'vms'],
#  ['what', 'locat', 'offer', 'job', 'use', 'java', 'on', 'sun'],
#  ['what', 'job', 'as', 'manufactur', 'manag', 'pay', '100000'],
#  ['are', 'there', 'ani', 'job', 'use', 'vc++'],
#  ['show', 'me', 'someth', 'that', 'requir', 'oracl'],
#  ['show', 'me', 'job', 'requir', 'a', 'bscs', 'on', 'sun'],
#  ['are', 'there', 'ani', 'project', 'manag', 'posit', 'open'],
#  ['are', 'there', 'ani', 'job', 'for', 'a', 'graphic', 'specialist'],
#  ['are', 'there', 'ani', 'job', 'with', 'a', 'salari', 'of', '100000'],
#  ['list', 'job', 'in', 'cobol', 'ii'],
#  ['what', 'job', 'in', 'california', 'pay', '60000', 'for', 'sql', 'develop'],
#  ['what', 'job', 'pay', '40000'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   '5',
#   'year',
#   'of',
#   'experi',
#   'but',
#   'desir',
#   '10',
#   'year',
#   'of',
#   'experi'],
#  ['show',
#   'the',
#   'job',
#   'with',
#   'the',
#   'titl',
#   'system',
#   'programm',
#   'requir',
#   '2',
#   'year',
#   'of',
#   'experien'],
#  ['what', 'job', 'are', 'there', 'use', 'sql'],
#  ['show', 'the', 'job', 'use', 'powerbuild'],
#  ['show', 'job', 'use', 'cic'],
#  ['are', 'there', 'ani', 'job', 'for', 'a', 'odbc', 'specialist'],
#  ['i',
#   'hold',
#   'a',
#   'degre',
#   'in',
#   'bscs',
#   'in',
#   'austin',
#   'are',
#   'there',
#   'ani',
#   'job',
#   'for',
#   'me'],
#  ['give', 'me', 'job', 'in', 'dalla'],
#  ['what', 'job', 'requir', 'knowledg', 'of', 'c++', 'but', 'not', 'perl'],
#  ['what', 'ai', 'job', 'are', 'there', 'in', 'texa', 'that', 'pay', '65000'],
#  ['what',
#   'job',
#   'are',
#   'avail',
#   'that',
#   'requir',
#   'java',
#   'but',
#   'not',
#   'internet',
#   'experi',
#   'or',
#   'ai',
#   'experi'],
#  ['what',
#   'web',
#   'job',
#   'are',
#   'avail',
#   'that',
#   'need',
#   'mac',
#   'experi',
#   'and',
#   'no',
#   'degre'],
#  ['show', 'me', 'job', 'at', 'dell', 'earn', '600'],
#  ['give', 'me', 'job', 'in', 'san', 'antonio', 'use', 'cobol'],
#  ['show',
#   'a',
#   'list',
#   'of',
#   'job',
#   'requir',
#   'experi',
#   'in',
#   'c++',
#   'or',
#   'java'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'outsid',
#   'austin',
#   'which',
#   'pay',
#   'less',
#   'than',
#   '60000',
#   'per',
#   'year'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'that',
#   'do',
#   'not',
#   'requir',
#   '5',
#   'year',
#   'of',
#   'experi'],
#  ['are', 'there', 'ani', 'comput', 'job', 'for', 'the', 'playstat'],
#  ['show', 'me', 'the', 'job', 'use', 'lisp', 'requir', 'a', 'bscs'],
#  ['show',
#   'the',
#   'job',
#   'offer',
#   '40000',
#   'work',
#   'with',
#   'c',
#   'on',
#   'window',
#   'nt'],
#  ['are', 'there', 'ani', 'job', 'special', 'in', 'ai', 'with', 'jpl'],
#  ['give',
#   'me',
#   'job',
#   'that',
#   'requir',
#   'ethernet',
#   'experi',
#   'but',
#   'no',
#   'html'],
#  ['show', 'me', 'houston', 'job', 'use', 'c++', 'on', 'pc'],
#  ['show',
#   'the',
#   'compani',
#   'that',
#   'are',
#   'look',
#   'for',
#   'bscs',
#   'in',
#   'aust'],
#  ['are', 'there', 'ada', 'job', 'outsid', 'austin'],
#  ['what', 'programm', 'posit', 'in', 'austin', 'requir', 'no', 'experi'],
#  ['are', 'there', 'ani', 'job', 'in', 'usa'],
#  ['doe',
#   'nation',
#   'instrument',
#   'have',
#   'ani',
#   'posit',
#   'that',
#   'dont',
#   'requir',
#   'experi'],
#  ['what',
#   'job',
#   'desir',
#   '2',
#   'year',
#   'of',
#   'experi',
#   'with',
#   'powerbuild',
#   'on',
#   'window',
#   'nt'],
#  ['show',
#   'the',
#   'job',
#   'offer',
#   '40000',
#   'work',
#   'with',
#   'c',
#   'on',
#   'window',
#   'nt'],
#  ['could', 'you', 'list', 'all', 'the', 'job'],
#  ['if',
#   'i',
#   'move',
#   'to',
#   'california',
#   'and',
#   'learn',
#   'sql',
#   'on',
#   'oracl',
#   'could',
#   'i',
#   'find',
#   'anyth',
#   'for',
#   '30000',
#   'on',
#   'unix'],
#  ['show', 'me', 'all', 'of', 'the', 'softwar', 'qa', 'job', 'in', 'austin'],
#  ['what', 'microsoft', 'job', 'do', 'not', 'requir', 'a', 'bscs'],
#  ['show', 'me', 'the', 'research', 'assist', 'job', 'in', 'austin'],
#  ['are', 'there', 'ani', 'system', 'administr', 'job', 'in', 'austin'],
#  ['show', 'the', 'job', 'in', 'visual', 'c++'],
#  ['are', 'there', 'ani', 'job', 'special', 'in', 'ai', 'with', 'jpl'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'onli',
#   'requir',
#   'a',
#   'bscs',
#   'and',
#   'no',
#   'experi'],
#  ['show', 'the', 'job', 'on', 'pc', 'requir', 'bscs'],
#  ['are', 'there', 'ani', 'job', 'in', 'austin'],
#  ['list', 'job', 'on', 'sun'],
#  ['are', 'there', 'ani', 'job', 'use', 'sql'],
#  ['show', 'me', 'the', 'job', 'with', 'a', 'salari', 'of', '50000'],
#  ['mvs', 'cobol', 'and', 'databas', 'are', 'the', 'key', 'to', 'tivoli'],
#  ['give', 'me', 'the', 'job', 'on', 'novel'],
#  ['what',
#   'are',
#   'the',
#   'posit',
#   'within',
#   'hp',
#   'that',
#   'pay',
#   '40000',
#   'per',
#   'year'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'at',
#   'appli',
#   'materi',
#   'that',
#   'requir',
#   'a',
#   'bscs'],
#  ['what', 'system', 'analyst', 'job', 'are', 'there', 'in', 'austin'],
#  ['are', 'there', 'ani', 'job', 'with', 'a', 'salari', 'of', '100000'],
#  ['show',
#   'job',
#   'that',
#   'do',
#   'not',
#   'requir',
#   'a',
#   'degre',
#   'for',
#   'visual',
#   'basic',
#   'programm'],
#  ['what', 'are', 'the', 'job', 'that', 'pay', '50000', 'per', 'year'],
#  ['what', 'posit', 'are', 'there', 'in', 'network'],
#  ['are', 'there', 'ani', 'job', 'on', 'window'],
#  ['are', 'there', 'ani', 'job', 'for', 'a', 'programm'],
#  ['do', 'ani', 'job', 'exist', 'program', 'for', 'appl', 'on', 'pdp11s'],
#  ['what', 'job', 'are', 'there', 'requir', 'ba'],
#  ['tell', 'me', 'the', 'job', 'on', 'window', 'nt'],
#  ['are', 'there', 'ani', 'job', 'for', 'a', 'client', 'server', 'specialist'],
#  ['give', 'me', 'job', 'in', 'san', 'antonio'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'for',
#   'pascal',
#   'program',
#   'who',
#   'dont',
#   'know',
#   'c+'],
#  ['what', 'job', 'in', 'austin', 'have', 'a', 'salari', 'of', '60000'],
#  ['find', 'all', 'c++', 'job', 'in', 'austin'],
#  ['tell', 'me', 'job', 'on', 'window', '95', 'in', 'mfc'],
#  ['what', 'system', 'administr', 'job', 'are', 'avail', 'from', 'dell'],
#  ['which', 'job', 'use', 'visual', 'j++', 'as', 'their', 'develop', 'tool'],
#  ['test',
#   'engin',
#   'in',
#   'need',
#   'of',
#   '40000',
#   'in',
#   'seattl',
#   'on',
#   'window',
#   'nt'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'in',
#   'austin',
#   'that',
#   'desir',
#   '3',
#   'year',
#   'of',
#   'experi',
#   'and',
#   'use',
#   'c++'],
#  ['what',
#   'oracl',
#   'job',
#   'are',
#   'there',
#   'with',
#   'compaq',
#   'in',
#   'houston',
#   'use',
#   'pc'],
#  ['list', 'job', 'requir', 'ba'],
#  ['there',
#   'must',
#   'be',
#   'some',
#   'job',
#   'out',
#   'there',
#   'for',
#   'a',
#   'c++',
#   'programm',
#   'that',
#   'think',
#   'in',
#   'unix',
#   'databas'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'in',
#   'austin',
#   'pay',
#   'over',
#   '100000',
#   'per',
#   'year'],
#  ['what',
#   'job',
#   'in',
#   'ibm',
#   'in',
#   'austin',
#   'do',
#   'not',
#   'need',
#   'a',
#   'degre'],
#  ['what', 'job', 'in', 'austin', 'requir', '10', 'year', 'of', 'experi'],
#  ['show',
#   'me',
#   'the',
#   'hardwar',
#   'platform',
#   'associ',
#   'with',
#   'a',
#   'netwar',
#   'administr',
#   'with',
#   'ibm'],
#  ['what', 'job', 'are', 'there', 'for', 'a', '3d', 'graphic', 'specialist'],
#  ['what', 'job', 'are', 'there', 'for', 'programm', 'who', 'know', 'java'],
#  ['show',
#   'me',
#   'a',
#   'job',
#   'not',
#   'requirng',
#   'java',
#   'and',
#   'not',
#   'in',
#   'austin'],
#  ['which', 'job', 'use', 'visual', 'j++', 'as', 'their', 'develop', 'tool'],
#  ['are', 'there', 'ani', 'job', 'on', 'ibm'],
#  ['show', 'job', 'for', 'a', 'com', 'specialist'],
#  ['which', 'job', 'requir', 'c', 'and', 'c++', 'but', 'not', 'java'],
#  ['what', 'do', 'you', 'have', 'pay', 'over', '40000', 'on', 'the', 'vax'],
#  ['give', 'me', 'job', 'on', 'the', 'mac', 'use', 'perl'],
#  ['show', 'me', 'c++', 'job', 'requir', 'a', 'bscs', 'in', 'austin'],
#  ['show',
#   'me',
#   'job',
#   'with',
#   'the',
#   'playstat',
#   'in',
#   'the',
#   'specialti',
#   'area',
#   'of',
#   'anim'],
#  ['what', 'job', 'are', 'there', 'for', 'a', 'graphic', 'specialist'],
#  ['what', 'job', 'in', 'austin', 'need', 'knowledg', 'in', 'unix'],
#  ['what', 'job', 'pay', '40000', 'per', 'year', 'that', 'requir', 'a', 'bscs'],
#  ['show',
#   'me',
#   'job',
#   'in',
#   'tulsa',
#   'use',
#   'fortran',
#   'on',
#   'vax',
#   'requir',
#   'a',
#   'bscs'],
#  ['give', 'me', 'the', 'job', 'in', 'dalla'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'use',
#   'java',
#   'that',
#   'are',
#   'not',
#   'with',
#   'tivoli'],
#  ['show', 'me', 'job', 'requir', 'no', 'experien'],
#  ['what',
#   'job',
#   'give',
#   'me',
#   '40000',
#   'to',
#   'work',
#   'in',
#   'houston',
#   'on',
#   'internet',
#   'and',
#   'web',
#   'with',
#   'perl'],
#  ['what', 'job', 'in', 'austin', 'have', 'a', 'salari', 'of', '60000'],
#  ['give', 'me', 'c++', 'job', 'on', 'window', 'nt'],
#  ['show',
#   'me',
#   'graphic',
#   'job',
#   'which',
#   'phil',
#   'smith',
#   'is',
#   'recruit',
#   'for'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'are',
#   'there',
#   'that',
#   'pay',
#   'at',
#   'least',
#   '100000',
#   'per',
#   'year'],
#  ['what',
#   'are',
#   'the',
#   'job',
#   'for',
#   'programm',
#   'in',
#   'austin',
#   'that',
#   'has',
#   'salari',
#   '50000',
#   'that',
#   'use',
#   'c++',
#   'and',
#   'not',
#   'relat',
#   'with',
#   'ai'],
#  ['what',
#   'job',
#   'requir',
#   'experi',
#   'in',
#   'c++',
#   'and',
#   'java',
#   'but',
#   'not',
#   'perl'],
#  ['what', 'job', 'at', 'dell', 'requir', 'a', 'bscs'],
#  ['give', 'me', 'the', 'job', 'use', 'cobol'],
#  ['what',
#   'job',
#   'in',
#   'boston',
#   'have',
#   'open',
#   'for',
#   'a',
#   'c++',
#   'programm'],
#  ['tell', 'me', 'what', 'job', 'there', 'are'],
#  ['what', 'job', 'are', 'there', 'use', 'cobol'],
#  ['show', 'the', 'job', 'on', 'sun'],
#  ['are',
#   'there',
#   'job',
#   'use',
#   'vb',
#   'in',
#   'seattl',
#   'with',
#   'sql',
#   'server',
#   'and',
#   'on',
#   'window',
#   'nt'],
#  ['show',
#   'me',
#   'the',
#   'c++',
#   'job',
#   'in',
#   'nashvill',
#   'that',
#   'desir',
#   '2',
#   'year',
#   'experi'],
#  ['i', 'want', 'a', 'job', 'that', 'use', 'c++'],
#  ['what', 'are', 'the', 'job', 'that', 'pay', '50000', 'per', 'year'],
#  ['show',
#   'me',
#   'job',
#   'with',
#   'a',
#   'salari',
#   'greater',
#   'than',
#   '50000',
#   'dollar',
#   'a',
#   'year'],
#  ['are', 'there', 'ani', 'job', 'requir', 'ba'],
#  ['are', 'there', 'ani', 'job', 'use', 'assembl', 'in', 'usa'],
#  ['show',
#   'me',
#   'job',
#   'at',
#   'dell',
#   'requir',
#   'no',
#   'experi',
#   'and',
#   'a',
#   'bscs'],
#  ['list', 'job', 'use', 'cobol', 'ii'],
#  ['list', 'the', 'job', 'use', 'cic'],
#  ['show',
#   'me',
#   'job',
#   'in',
#   'austin',
#   'use',
#   'solari',
#   'that',
#   'do',
#   'not',
#   'requir',
#   'a',
#   'bscs'],
#  ['show', 'job', 'on', 'window'],
#  ['show', 'the', 'job', 'use', 'html'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'that',
#   'dont',
#   'requir',
#   'a',
#   'degre',
#   'but',
#   'use',
#   'perl'],
#  ['show', 'me', 'system', 'analyst', 'job', 'at', 'ibm'],
#  ['what', 'job', 'pay', 'at', 'least', '80000', 'dollar', 'per', 'year'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'in',
#   'texa',
#   'that',
#   'use',
#   'java',
#   'and',
#   'requir',
#   'no',
#   'experi'],
#  ['[which',
#   'job',
#   'requir',
#   'knowledg',
#   'of',
#   'lisp',
#   'but',
#   'dont',
#   'special',
#   'in',
#   'ai'],
#  ['where', 'can', 'i', 'work', 'with', 'a', 'bscs', 'and', 'no', 'experi'],
#  ['show',
#   'me',
#   'houston',
#   'job',
#   'use',
#   'c',
#   'in',
#   'the',
#   'specialti',
#   'area',
#   'of',
#   'oil',
#   'pipelin',
#   'model'],
#  ['what',
#   'job',
#   'in',
#   'austin',
#   'are',
#   'for',
#   'a',
#   'lisp',
#   'programm',
#   'that',
#   'involv',
#   'unix',
#   'and',
#   'the',
#   'internet'],
#  ['tell', 'me', 'job', 'requir', 'bscs'],
#  ['list', 'the', 'compani', 'that', 'desir', 'c++', 'experi'],
#  ['what', 'job', 'use', 'fortran', 'are', 'there', 'in', 'houston'],
#  ['show', 'me', 'develop', 'job', 'requir', 'experi', 'with', 'mac'],
#  ['what', 'job', 'in', 'austin', 'requir', 'no', 'experi'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'for',
#   'austin',
#   'mac',
#   'programm',
#   'use',
#   'c++'],
#  ['what', 'are', 'the', 'job', 'use', 'c++', 'with', 'salari', 'of', '50000'],
#  ['give', 'me', 'the', 'job', 'on', 'unix'],
#  ['what', 'job', 'pay', '40000', 'per', 'year', 'that', 'desir', 'a', 'bscs'],
#  ['what', 'job', 'are', 'there', 'for', 'a', 'visual', 'basic', 'develop'],
#  ['give',
#   'me',
#   'the',
#   'job',
#   'use',
#   'c++',
#   'that',
#   'dont',
#   'requir',
#   'window'],
#  ['give', 'me', 'job', 'in', 'dalla'],
#  ['what', 'system', 'administr', 'job', 'are', 'avail', 'from', 'dell'],
#  ['greed',
#   'for',
#   '80000',
#   'and',
#   'java',
#   'plagu',
#   'develop',
#   'want',
#   'to',
#   'live',
#   'in',
#   'san',
#   'jose',
#   'at',
#   'appl'],
#  ['tell', 'me', 'the', 'job', 'on', 'mvs'],
#  ['what', 'job', 'are', 'there', 'in', 'dalla', 'that', 'requir', 'a', 'mscs'],
#  ['show', 'me', 'c++', 'job', 'requir', 'a', 'bscs', 'in', 'austin'],
#  ['what', 'job', 'need', 'at', 'least', '2', 'year', 'of', 'experi'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'at',
#   'dell',
#   'that',
#   'requir',
#   'no',
#   'experi',
#   'and',
#   'pay',
#   '50000'],
#  ['show', 'me', 'posit', 'in', 'web', 'program'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'in',
#   'austin',
#   'that',
#   'requir',
#   'experi',
#   'with',
#   'unix'],
#  ['are', 'there', 'ani', 'mac', 'programm', 'job', 'open', 'in', 'austin'],
#  ['show',
#   'job',
#   'that',
#   'are',
#   'not',
#   'in',
#   'austin',
#   'pay',
#   'less',
#   'than',
#   '10000',
#   'requir',
#   'knowledg',
#   'of',
#   'c++',
#   'pascal',
#   'and',
#   'java',
#   'and',
#   'desir',
#   'a',
#   'phd'],
#  ['can', 'you', 'show', 'me', 'all', 'the', 'job'],
#  ['what',
#   'engin',
#   'posit',
#   'in',
#   'telecommun',
#   'compani',
#   'in',
#   'dalla',
#   'do',
#   'not',
#   'requir',
#   'c++'],
#  ['tell', 'me', 'the', 'job', 'in', 'usa'],
#  ['what', 'is', 'out', 'there'],
#  ['what', 'ibm', 'job', 'requir', 'use', 'java', 'on', 'commodor'],
#  ['show',
#   'me',
#   'job',
#   'in',
#   'austin',
#   'that',
#   'use',
#   'java',
#   'on',
#   'unix',
#   'for',
#   'a',
#   'develop',
#   'pay',
#   'at',
#   'least',
#   '50000'],
#  ['i', 'would', 'like', 'to', 'find', 'a', 'job', 'use', 'java'],
#  ['what', 'job', 'requir', 'a', 'bscs', 'and', 'no', 'experi'],
#  ['can',
#   'i',
#   'find',
#   'a',
#   'job',
#   'make',
#   'more',
#   'than',
#   '40000',
#   'a',
#   'year',
#   'without',
#   'a',
#   'degre'],
#  ['list', 'the', 'job', 'in', 'san', 'antonio'],
#  ['what', 'job', 'use', 'html', 'but', 'do', 'not', 'requir', 'a', 'degre'],
#  ['what',
#   'are',
#   'the',
#   'job',
#   'that',
#   'requir',
#   'experi',
#   'with',
#   'microsoft',
#   'word'],
#  ['show', 'me', 'the', 'job', 'that', 'requir', '2', 'year', 'experi'],
#  ['what', 'job', 'are', 'there', 'requir', 'bsee'],
#  ['what', 'job', 'in', 'houston', 'requir', 'a', 'bac'],
#  ['what',
#   'program',
#   'languag',
#   'are',
#   'desir',
#   'for',
#   'a',
#   'job',
#   'as',
#   'a',
#   'programm',
#   'at',
#   'ibm'],
#  ['show', 'me', 'what', 'need', 'experi'],
#  ['list', 'job', 'in', 'client', 'server'],
#  ['what', 'job', 'are', 'longhorn', 'employ', 'hire', 'for'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'for',
#   'web',
#   'develop',
#   'who',
#   'know',
#   'c++'],
#  ['what', 'databas', 'job', 'are', 'there'],
#  ['give', 'me', 'a', 'list', 'of', 'all', 'the', 'job'],
#  ['list', 'the', 'job', 'use', 'html', 'for', 'a', 'game', 'specialist'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'concern',
#   'game',
#   'develop',
#   'on',
#   'a',
#   'playstat'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'work',
#   'for',
#   'microsoft',
#   'program',
#   'lisp',
#   'for',
#   'autocad'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'at',
#   'dell',
#   'that',
#   'requir',
#   'no',
#   'experi',
#   'and',
#   'pay',
#   '50000'],
#  ['what', 'web', 'relat', 'job', 'requir', 'a', 'bscs', 'but', 'no', 'experi'],
#  ['what', 'job', 'in', 'dalla', 'requir', 'experi', 'with', 'unix'],
#  ['what',
#   'program',
#   'job',
#   'are',
#   'there',
#   'in',
#   'austin',
#   'that',
#   'use',
#   'java'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   'at',
#   'least',
#   'a',
#   'bscs',
#   'and',
#   'know',
#   'latex'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'in',
#   'austin',
#   'for',
#   'peopl',
#   'with',
#   'knowledg',
#   'of',
#   'the',
#   'applic',
#   'oracl'],
#  ['are', 'there', 'ani', 'job', 'on', 'pc'],
#  ['show', 'me', 'new', 'york', 'job', 'requir', 'a', 'bscs'],
#  ['are', 'there', 'ani', 'job', 'requir', 'bsee'],
#  ['show',
#   'me',
#   'job',
#   'in',
#   'austin',
#   'use',
#   'solari',
#   'that',
#   'do',
#   'not',
#   'requir',
#   'a',
#   'bscs'],
#  ['tell', 'me', 'job', 'in', 'network'],
#  ['give', 'me', 'the', 'job', 'requir', 'bscs'],
#  ['show', 'me', 'job', 'at', 'dell', 'requir', 'a', 'bscs', 'degre'],
#  ['give', 'me', 'the', 'job', 'on', 'window', 'nt'],
#  ['show', 'the', 'job', 'requir', 'bs', 'in', 'usa'],
#  ['show', 'me', 'austin', 'job', 'with', 'a', 'salari', 'of', '500'],
#  ['who', 'might', 'offer', 'me', '50000', 'for', 'web', 'develop'],
#  ['what',
#   'job',
#   'requir',
#   'a',
#   'degre',
#   'for',
#   'pascal',
#   'programm',
#   'who',
#   'do',
#   'not',
#   'know',
#   'c++'],
#  ['what', 'job', 'are', 'there', 'in', 'odbc'],
#  ['show', 'me', 'programm', 'job', 'requir', 'no', 'experi', 'on', 'unix'],
#  ['show', 'me', 'all', 'job', 'that', 'are', 'availab'],
#  ['what',
#   'job',
#   'are',
#   'avail',
#   'use',
#   'apach',
#   'with',
#   'a',
#   'specialti',
#   'area',
#   'of',
#   'network'],
#  ['what', 'level', 'of', 'experi', 'doe', 'ibm', 'desir'],
#  ['show', 'job', 'use', 'powerbuild'],
#  ['are', 'there', 'ani', 'mac', 'programm', 'job'],
#  ['show', 'the', 'job', 'on', 'vms'],
#  ['are', 'there', 'ani', 'mac', 'job', 'open'],
#  ['are', 'there', 'ani', 'programm', 'job', 'open'],
#  ['id', 'like', 'to', 'see', 'everyth'],
#  ['show', 'me', 'everyth'],
#  ['what', 'job', 'requir', 'a', 'bscs', 'and', 'experi', 'with', 'oracl'],
#  ['give', 'me', 'job', 'requir', 'bs'],
#  ['list',
#   'the',
#   'posit',
#   'that',
#   'requir',
#   'a',
#   'knowledg',
#   'of',
#   'microsoft',
#   'excel'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'use',
#   'perl',
#   'with',
#   'lockhe',
#   'martin',
#   'aeronaut',
#   'in',
#   'colorado'],
#  ['are', 'there', 'ani', 'job', 'requir', 'bscs'],
#  ['show', 'job', 'in', 'html'],
#  ['show', 'job', 'requir', 'ba'],
#  ['what', 'are', 'the', 'c++', 'job', 'in', 'austin', 'requir', 'a', 'bscs'],
#  ['what', 'are', 'the', 'c++', 'job', 'in', 'austin', 'requir', 'a', 'bscs'],
#  ['which',
#   'system',
#   'administr',
#   'job',
#   'in',
#   'dalla',
#   'requir',
#   '2',
#   'year',
#   'experi',
#   'and',
#   'pay',
#   '50000'],
#  ['what', 'job', 'use', 'c++', 'on', 'mac', 'and', 'pay', '70000'],
#  ['show', 'the', 'job', 'in', 'dalla'],
#  ['give', 'me', 'the', 'job', 'for', 'a', 'game', 'specialist'],
#  ['are', 'there', 'ani', 'job', 'in', 'austin'],
#  ['list', 'job', 'on', 'window'],
#  ['show',
#   'me',
#   'job',
#   'in',
#   'tulsa',
#   'use',
#   'fortran',
#   'on',
#   'vax',
#   'requir',
#   'a',
#   'bscs'],
#  ['are', 'there', 'ani', 'job', 'use', 'c++', 'with', 'dell'],
#  ['what', 'job', 'are', 'there', 'use', 'rpg'],
#  ['show',
#   'the',
#   'job',
#   'use',
#   'lisp',
#   'not',
#   'requir',
#   'a',
#   'degre',
#   'in',
#   'cs'],
#  ['what',
#   'job',
#   'are',
#   'in',
#   'seattl',
#   'that',
#   'are',
#   'not',
#   'at',
#   'microsoft'],
#  ['tell', 'me', 'job', 'for', 'a', 'devic', 'driver', 'specialist'],
#  ['show', 'me', 'austin', 'job', 'with', 'a', 'salari', 'of', '50000'],
#  ['which', 'job', 'at', 'trilog', 'deal', 'with', 'c++'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'in',
#   'austin',
#   'develop',
#   'game',
#   'in',
#   'x86',
#   'use',
#   'assembl'],
#  ['all', 'of', 'it'],
#  ['what', 'job', 'desir', 'a', 'degre', 'but', 'dont', 'use', 'c++'],
#  ['tell', 'me', 'the', 'job', 'use', 'powerbuild'],
#  ['what', 'can', 'i', 'find', 'use', 'java', 'on', 'unix'],
#  ['what', 'job', 'is', 'there', 'for', 'c++', 'but', 'not', 'visual', 'c++'],
#  ['which',
#   'job',
#   'in',
#   'austin',
#   'offer',
#   'for',
#   'student',
#   'fresh',
#   'out',
#   'of',
#   'colleg',
#   'in',
#   'network'],
#  ['give', 'me', 'job', 'in', 'usa'],
#  ['show', 'job', 'in', 'austin', 'that', 'requir', 'a', 'bscs'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'requir',
#   'a',
#   'bscs',
#   'for',
#   'boe',
#   'in',
#   'seattl'],
#  ['which', 'job', 'pay', '60000', 'that', 'do', 'not', 'requir', 'a', 'phd'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'for',
#   'window',
#   'nt',
#   'develop',
#   'that',
#   'know',
#   'oracl'],
#  ['give', 'me', 'the', 'job', 'on', 'vms', 'in', 'assembl'],
#  ['list', 'the', 'job', 'requir', 'bs'],
#  ['what', 'all', 'there'],
#  ['are', 'there', 'ani', 'programm', 'job', 'open'],
#  ['are', 'there', 'ani', 'mac', 'programm', 'job'],
#  ['tell', 'me', 'the', 'job', 'requir', 'bs'],
#  ['show',
#   'me',
#   'a',
#   'job',
#   'not',
#   'requirng',
#   'java',
#   'and',
#   'not',
#   'in',
#   'austin'],
#  ['what',
#   'job',
#   'pay',
#   '60000',
#   'are',
#   'locat',
#   'in',
#   'austin',
#   'and',
#   'requir',
#   'a',
#   'bscs'],
#  ['move',
#   'to',
#   'canada',
#   'need',
#   'a',
#   'job',
#   'with',
#   'unix',
#   'java',
#   'and',
#   'ibm'],
#  ['what',
#   'are',
#   'the',
#   'job',
#   'in',
#   'austin',
#   'requir',
#   'knowledg',
#   'of',
#   'oracl'],
#  ['which',
#   'job',
#   'are',
#   'for',
#   'bsee',
#   'major',
#   'with',
#   'at',
#   'least',
#   '5',
#   'year',
#   'experi',
#   'in',
#   'window',
#   'nt'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'in',
#   'c++',
#   'that',
#   'the',
#   'salari',
#   'is',
#   '50000'],
#  ['find', 'all', 'network', 'administr', 'job', 'in', 'austin'],
#  ['what',
#   'job',
#   'in',
#   'boston',
#   'have',
#   'open',
#   'for',
#   'a',
#   'c++',
#   'programm'],
#  ['what',
#   'tivoli',
#   'job',
#   'are',
#   'there',
#   'that',
#   'requir',
#   'a',
#   'bscs',
#   'degre'],
#  ['show', 'me', 'job', 'locat', 'in', 'austin', 'for', 'c++', 'programm'],
#  ['what', 'ai', 'posit', 'requir', 'onli', 'a', 'bscs'],
#  ['can',
#   'you',
#   'offer',
#   'anyth',
#   'with',
#   'at',
#   'least',
#   '60000',
#   'on',
#   'a',
#   'sun'],
#  ['show',
#   'me',
#   'job',
#   'use',
#   'lisp',
#   'that',
#   'requir',
#   'a',
#   'bscs',
#   'and',
#   'desir',
#   'a',
#   'msee'],
#  ['show', 'me', 'job', 'not', 'involv', 'c++'],
#  ['show', 'me', 'the', 'job', 'with', '30000', 'sala'],
#  ['all', 'the', 'job', 'pleas'],
#  ['what', 'are', 'the', 'softwar', 'engin', 'job', 'avail', 'use', 'ada'],
#  ['what', 'job', 'requir', 'a', 'bscs'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'work',
#   'for',
#   'microsoft',
#   'program',
#   'lisp',
#   'for',
#   'autocad'],
#  ['what', 'job', 'are', 'there', 'use', 'vc++'],
#  ['what',
#   'job',
#   'in',
#   'san',
#   'antonio',
#   'requir',
#   'the',
#   'use',
#   'of',
#   'cobol'],
#  ['show', 'me', 'job', 'requir', 'a', 'bscs', 'on', 'sun'],
#  ['show', 'me', 'job', 'pay', 'greater', 'than', '50000', 'per', 'year'],
#  ['what',
#   'job',
#   'requir',
#   '10',
#   'year',
#   'of',
#   'experi',
#   'requir',
#   'a',
#   'phd',
#   'in',
#   'cs',
#   'are',
#   'in',
#   'cobol',
#   'and',
#   'are',
#   'locat',
#   'in',
#   'texa'],
#  ['what', 'job', 'are', 'there', 'on', 'window', 'nt'],
#  ['are',
#   'there',
#   'ani',
#   'job',
#   'use',
#   'java',
#   'that',
#   'dont',
#   'requir',
#   'a',
#   'bscs'],
#  ['tell', 'me', 'the', 'job', 'requir', 'ba', 'use', 'cobol'],
#  ['show', 'me', 'what', 'job', 'there', 'are'],
#  ['who', 'give', '50000', 'for', 'fortran'],
#  ['show', 'me', 'the', 'job', 'that', 'oper', 'on', 'sun'],
#  ['what', 'job', 'have', 'a', 'recruit', 'name', 'phil', 'smith'],
#  ['give', 'me', 'job', 'requir', 'bs'],
#  ['what',
#   'job',
#   'are',
#   'there',
#   'for',
#   'c++',
#   'programm',
#   'which',
#   'pay',
#   'more',
#   'than',
#   '60000',
#   'per',
#   'year'],
#  ['show', 'me', 'all', 'of', 'the', 'softwar', 'engin', 'job', 'in', 'austin'],
#  ['show', 'the', 'job', 'for', 'bscs', 'in', 'austin'],
#  ['i', 'want', 'a', 'job', 'that', 'doesnt', 'use', 'window'],
#  ['what', 'job', 'in', 'houston', 'requir', 'a', 'bac'],
#  ['what', 'work', 'do', 'you', 'have', 'avail'],
#  ['show',
#   'me',
#   'the',
#   'senior',
#   'softwar',
#   'develop',
#   'job',
#   'which',
#   'requir',
#   'a',
#   'master'],
#  ['show',
#   'me',
#   'the',
#   'job',
#   'requir',
#   '3',
#   'year',
#   'of',
#   'experi',
#   'at',
#   'tivoli'],
#  ['i', 'would', 'like', 'to', 'see', 'all', 'the', 'job'],
#  ['what',
#   'kind',
#   'of',
#   'job',
#   'could',
#   'i',
#   'find',
#   'for',
#   'an',
#   'old',
#   'cobol',
#   'programm'],
#  ['what', 'are', 'the', 'job', 'use', 'c++', 'with', 'salari', 'of', '50000']]

# %%
from collections import Counter

input_vocab = Counter()
for l in inputs_train:
  input_vocab.update(l)

input_word2idx = {}
for w, c in input_vocab.items():
  if c >= 2:
    input_word2idx[w] = len(input_word2idx)
input_word2idx['<UNK>'] = len(input_word2idx)
input_word2idx['<PAD>'] = len(input_word2idx)
input_idx2word = {i:word for word,i in input_word2idx.items()}

input_vocab = list(input_word2idx.keys())

query_vocab = Counter()
for q in queries_train:
  query_vocab.update(q)
query_vocab['<UNK>'] = 0
query_vocab['<PAD>'] = 0
query_idx2word = {i:word for i, word in enumerate(query_vocab.keys())}
query_word2idx = {word:i for i, word in query_idx2word.items()}

# %%
print('input vocab size:', len(input_word2idx))
print(input_word2idx)
print('query vocab size:', len(query_word2idx))
print(query_word2idx)
# Out:
# input vocab size: 229
# {'what': 0, 'job': 1, 'are': 2, 'there': 3, 'use': 4, 'show': 5, 'me': 6, 'the': 7, 'c++': 8, 'that': 9, 'requir': 10, 'a': 11, 'bscs': 12, 'but': 13, 'desir': 14, 'mscs': 15, 'for': 16, 'network': 17, 'specialist': 18, 'give': 19, 'in': 20, 'visual': 21, 'list': 22, 'bsee': 23, 'databas': 24, 'usa': 25, 'can': 26, 'develop': 27, 'find': 28, 'san': 29, 'antonio': 30, 'on': 31, 'window': 32, 'ba': 33, 'i': 34, 'jpl': 35, 'doe': 36, 'unix': 37, 'with': 38, 'prolog': 39, 'and': 40, 'vax': 41, 'avail': 42, 'solari': 43, 'system': 44, 'administr': 45, 'degre': 46, 'an': 47, 'ani': 48, 'comput': 49, 'of': 50, 'java': 51, '2': 52, 'year': 53, 'experi': 54, 'texa': 55, 'ai': 56, 'cobol': 57, 'ibm': 58, 'machin': 59, 'pay': 60, '70000': 61, 'posit': 62, 'onli': 63, 'austin': 64, 'tell': 65, 'mfc': 66, 'data': 67, 'wareh': 68, '60000': 69, 'locat': 70, 'powerbuild': 71, 'as': 72, 'senior': 73, 'softwar': 74, 'houston': 75, 'not': 76, 'nashvill': 77, 'experien': 78, 'ii': 79, 'at': 80, 'least': 81, 'know': 82, 'latex': 83, 'knowledg': 84, 'linux': 85, 'oracl': 86, 'compaq': 87, 'all': 88, 'manag': 89, 'boston': 90, 'basic': 91, 'is': 92, 'want': 93, 'microsoft': 94, 'sql': 95, 'vms': 96, 'do': 97, 'you': 98, 'have': 99, 'lisp': 100, 'graphic': 101, 'recruit': 102, 'anyon': 103, 'offer': 104, '40000': 105, 'work': 106, 'bs': 107, 'web': 108, 'open': 109, 'trilog': 110, 'ada': 111, 'outsid': 112, 'appl': 113, 'engin': 114, 'longhorn': 115, 'employ': 116, 'hire': 117, 'autocad': 118, 'html': 119, 'dalla': 120, 'more': 121, 'than': 122, '50000': 123, 'mvs': 124, 'game': 125, 'who': 126, 'dell': 127, 'tivoli': 128, 'project': 129, '10': 130, 'phd': 131, '3': 132, 'salari': 133, 'assembl': 134, 'which': 135, 'over': 136, 'research': 137, 'assist': 138, 'aust': 139, '1': 140, 'fortran': 141, 'msee': 142, 'silicon': 143, 'applic': 144, 'no': 145, '5': 146, 'california': 147, 'deal': 148, 'dont': 149, 'boe': 150, 'seattl': 151, 'could': 152, 'some': 153, 'platform': 154, 'greater': 155, '500': 156, 'per': 157, 'jose': 158, 'programm': 159, 'titl': 160, 'pascal': 161, 'program': 162, 'concern': 163, 'playstat': 164, 'mac': 165, 'tulsa': 166, 'sun': 167, 'consult': 168, 'everyth': 169, 'client': 170, 'server': 171, 'would': 172, 'like': 173, 'perl': 174, 'involv': 175, 'or': 176, '30000': 177, 'apach': 178, 'specialti': 179, 'area': 180, 'word': 181, 'major': 182, 'nt': 183, 'washington': 184, 'x86': 185, 'analyst': 186, 'anyth': 187, 'old': 188, 'excel': 189, 'vc++': 190, 'internet': 191, 'commodor': 192, 'peopl': 193, 'to': 194, 'student': 195, 'fresh': 196, 'out': 197, 'colleg': 198, 'compani': 199, 'kind': 200, 'c': 201, 'oil': 202, 'pipelin': 203, 'model': 204, 'pc': 205, 'test': 206, '100000': 207, 'cic': 208, 'odbc': 209, 'need': 210, 'less': 211, 'special': 212, 'move': 213, 'from': 214, 'j++': 215, 'their': 216, 'tool': 217, 'requirng': 218, 'phil': 219, 'smith': 220, 'relat': 221, 'dollar': 222, '80000': 223, 'bac': 224, 'see': 225, 'cs': 226, '<UNK>': 227, '<PAD>': 228}
# query vocab size: 503
# {'<s>': 0, 'answer': 1, '(': 2, '_1973': 3, ',': 4, 'job': 5, ')': 6, 'language': 7, '_1990': 8, 'const': 9, "'": 10, 'tcl': 11, '/': 12, 'tk': 13, '</s>': 14, 'c': 15, 'l': 16, '+': 17, 'req_deg': 18, 'd': 19, 'bscs': 20, 'des_deg': 21, 'e': 22, 'mscs': 23, '_3359': 24, 'area': 25, '_3378': 26, 'networking': 27, '_5851': 28, '_5868': 29, 'visual': 30, '_7125': 31, '_7138': 32, 'bsee': 33, '_1865': 34, '_1884': 35, 'database': 36, 'loc': 37, '_1896': 38, 'usa': 39, 'j': 40, 'delphi': 41, 'title': 42, 't': 43, 'developer': 44, 'san': 45, 'antonio': 46, 'platform': 47, 'p': 48, 'windows': 49, '_5753': 50, '_5766': 51, 'ba': 52, 'company': 53, 'jpl': 54, 'unix': 55, 'prolog': 56, 'q': 57, 'vax': 58, 'solaris': 59, 'systems': 60, 'administrator': 61, 'a': 62, 'b': 63, 'm': 64, 'statistics': 65, 'java': 66, 'req_exp': 67, '2': 68, 's': 69, 'texas': 70, 'ai': 71, 'cobol': 72, 'i': 73, 'ibm': 74, 'salary_greater_than': 75, '70000': 76, 'year': 77, '_5171': 78, '_5188': 79, 'austin': 80, '_2043': 81, '_2060': 82, 'mfc': 83, '_651': 84, '_666': 85, 'data': 86, 'warehousing': 87, '_5311': 88, '_5326': 89, '60000': 90, '_4433': 91, '_4450': 92, 'powerbuilder': 93, 'w': 94, 'senior': 95, 'software': 96, 'c1': 97, 'houston': 98, '\\': 99, 'c2': 100, '_4285': 101, '_4298': 102, 'nashville': 103, 'des_exp': 104, '_5889': 105, '_5904': 106, 'ii': 107, 'z': 108, 'latex': 109, 'linux': 110, 'oracle': 111, 'compaq': 112, 'pc': 113, 'management': 114, 'boston': 115, 'mba': 116, 'basic': 117, 'microsoft': 118, '_3149': 119, '_3162': 120, 'sql': 121, '_1833': 122, '_1846': 123, 'network': 124, '_2685': 125, '_2702': 126, 'vms': 127, 'g': 128, 'lisp': 129, 'h': 130, 'graphics': 131, '_1405': 132, '_1420': 133, 'recruiter': 134, 'lcs': 135, '40000': 136, 'web': 137, 'trilogy': 138, 'ada': 139, 'apple': 140, 'engineer': 141, 'longhorn': 142, '_5033': 143, '_5046': 144, 'wan': 145, '_2939': 146, '_2956': 147, '_2575': 148, '_2590': 149, '_5569': 150, '_5586': 151, '_4795': 152, '_4812': 153, 'application': 154, 'autocad': 155, '_6109': 156, '_6124': 157, 'html': 158, 'dallas': 159, '50000': 160, 'mvs': 161, '_1727': 162, '_1746': 163, 'games': 164, 'dell': 165, 'tivoli': 166, '_1691': 167, '_1708': 168, 'project': 169, 'manager': 170, 'y': 171, '10': 172, 'phd': 173, '3': 174, '_1037': 175, '_1052': 176, 'assembly': 177, '_2117': 178, '_2134': 179, 'research': 180, 'assistant': 181, '_405': 182, '_422': 183, '_1549': 184, '_1566': 185, 'u': 186, '1': 187, 'f': 188, 'fortran': 189, 'los': 190, 'alamos': 191, 'msee': 192, 'silicon': 193, 'ic': 194, 'design': 195, '_1229': 196, '_1242': 197, '_1256': 198, 'bs': 199, '_5925': 200, '_5940': 201, '5': 202, 'intern': 203, 'california': 204, 'x': 205, 'tcp': 206, 'ip': 207, '_5819': 208, '_5832': 209, 'boeing': 210, 'seattle': 211, '_4015': 212, '_4032': 213, 'jose': 214, 'programmer': 215, 'pascal': 216, '_343': 217, '_356': 218, '_4149': 219, '_4166': 220, 'playstation': 221, 'ma': 222, '_7021': 223, '_7038': 224, '_3109': 225, '_3128': 226, 'lan': 227, '_3641': 228, '_3656': 229, '_3007': 230, '_3020': 231, '_2523': 232, '_2540': 233, '_2550': 234, 'shell': 235, 'mac': 236, 'tulsa': 237, 'sun': 238, 'consulting': 239, '_7057': 240, '_7074': 241, 'system': 242, '_3607': 243, '_3622': 244, '_6453': 245, '_6470': 246, 'client': 247, 'server': 248, 'perl': 249, ';': 250, '30000': 251, 'apache': 252, 'r': 253, 'word': 254, '_4757': 255, '_4774': 256, '_441': 257, '_456': 258, '_689': 259, '_702': 260, '_712': 261, 'haskell': 262, 'nt': 263, 'washington': 264, '_5277': 265, '_5294': 266, 'x86': 267, 'analyst': 268, 'excel': 269, '_3435': 270, '_3452': 271, 'vc': 272, '_4217': 273, '_4230': 274, 'internet': 275, 'commodores': 276, 'aix': 277, '_4315': 278, '_4332': 279, '_4342': 280, '_2861': 281, '_2880': 282, '_6069': 283, '_6088': 284, '_3979': 285, '_3996': 286, 'consultant': 287, '_1107': 288, '_1122': 289, '_1132': 290, 'oil': 291, 'pipeline': 292, 'modeling': 293, '_5959': 294, '_5976': 295, '_5535': 296, ' ...

# %%
inputs_train_tokens = [[input_word2idx.get(w, input_word2idx['<UNK>']) for w in l] for l in inputs_train]
inputs_test_tokens = [[input_word2idx.get(w, input_word2idx['<UNK>']) for w in l] for l in inputs_test]

queries_train_tokens = [[query_word2idx.get(w, query_word2idx['<UNK>']) for w in l] for l in queries_train]
queries_test_tokens = [[query_word2idx.get(w, query_word2idx['<UNK>']) for w in l] for l in queries_test]

def pad(input_seq, max_len, pad_token_idx):
  input_seq = input_seq[:max_len]
  padded_seq = input_seq + (max_len - len(input_seq)) * [pad_token_idx]
  return padded_seq

inputs_max_target_len = max([len(i) for i in inputs_train_tokens])
inputs_train_tokens = [pad(i, inputs_max_target_len, input_word2idx['<PAD>']) for i in inputs_train_tokens]
inputs_test_tokens = [pad(i, inputs_max_target_len, input_word2idx['<PAD>']) for i in inputs_test_tokens]

queries_max_target_len = int(max([len(i) for i in queries_train_tokens]) * 1.5)
queries_train_tokens = [pad(i, queries_max_target_len, query_word2idx['<PAD>']) for i in queries_train_tokens]
queries_test_tokens = [pad(i, queries_max_target_len, query_word2idx['<PAD>']) for i in queries_test_tokens]

# %% [markdown]
# # Data Loading

# %%
from torch.utils.data import Dataset, DataLoader, default_collate
import torch
import torch.nn as nn
class JobsDataset(Dataset):
  def __init__(self, inputs, queries):
    self.inputs = inputs
    self.queries = queries

  def __len__(self):
      return len(self.inputs)

  def __getitem__(self, idx):
      return self.inputs[idx], self.queries[idx]

def build_datasets():
  jobs_train = JobsDataset(inputs=inputs_train_tokens, queries=queries_train_tokens)
  jobs_test = JobsDataset(inputs=inputs_test_tokens, queries=queries_test_tokens)
  return jobs_train, jobs_test

def collate(batch):
  src, tgt = default_collate(batch)
  return torch.stack(src), torch.stack(tgt)

def build_dataloaders(dataset_train, dataset_test, train_batch_size):
  dataloader_train = DataLoader(dataset_train, batch_size=train_batch_size, shuffle=True, collate_fn=collate)
  dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=False, collate_fn=collate)
  return dataloader_train, dataloader_test

# %% [markdown]
# # Todo: Define model

# %%
def create_model():

  input_vocab_sz = len(input_word2idx)
  query_vocab_sz = len(query_word2idx)

  emb_sz = 256
  hidden_sz = 128
  nlayers = 2

  encoder = Encoder(input_vocab_sz, emb_sz, hidden_sz, nlayers)
  decoder = Decoder(query_vocab_sz, emb_sz, hidden_sz, nlayers)

  model = Seq2Seq(encoder, decoder, hidden_sz, query_vocab_sz)

  return model

class Encoder(nn.Module):

  def __init__(self, vocab_sz, emb_sz, hidden_sz, nlayers=2):
    super().__init__()
    self.hidden_sz = hidden_sz
    self.nlayers = nlayers
    self.embedding = nn.Embedding(vocab_sz, emb_sz)
    self.lstm = nn.LSTM(emb_sz, hidden_sz, nlayers)

  def forward(self, inputs):
    seq_embedding = self.embedding(inputs)
    encoder_output, (hidden_state, cell) = self.lstm(seq_embedding)
    return encoder_output, hidden_state, cell


class Decoder(nn.Module):

  def __init__(self, vocab_sz, emb_sz, hidden_sz, nlayers=2):
    super().__init__()
    self.hidden_sz = hidden_sz
    self.vocab_sz = vocab_sz
    self.embedding = nn.Embedding(vocab_sz, emb_sz)
    self.lstm = nn.LSTM(emb_sz, hidden_sz, nlayers)


  def forward(self, inputs, hidden_state, cell):
    query_embedding = self.embedding(inputs)
    decoder_outputs, (decoder_hidden_state, decoder_cell) = self.lstm(query_embedding, (hidden_state, cell))
    return decoder_outputs, decoder_hidden_state, decoder_cell

  
class Seq2Seq(nn.Module):

  def __init__(self, encoder, decoder, hidden_sz, output_vocab_sz):
    super().__init__()
    self.encoder = encoder
    self.decoder = decoder

    self.W1 = nn.Linear(hidden_sz, hidden_sz)
    self.W2 = nn.Linear(hidden_sz, hidden_sz)
    self.W0 = nn.Linear(hidden_sz, output_vocab_sz)


  # def post_decode_with_attn(self, encoder_outputs, decoder_logits, decoder_hidden_state):
  #   htl = decoder_hidden_state[-1]

  def decode(self, labels, encoder_outputs, encoder_state, encoder_cell):

    logits, decoder_hidden_state, decoder_cell = self.decoder(labels, encoder_state, encoder_cell)
    htl = decoder_hidden_state[-1]

    numerator = torch.exp(encoder_outputs * htl)
    denominator = torch.sum(numerator, dim=0)

    scores = numerator / denominator

    c = torch.sum(scores * encoder_outputs, dim=0)

    h_attns = torch.tanh(self.W1(logits) + self.W2(c))

    return self.W0(h_attns)

  def forward(self, inputs, labels):
    encoder_outputs, encoder_state, encoder_cell = self.encoder(inputs)
    return self.decode(labels, encoder_outputs, encoder_state, encoder_cell)
    # logits, decoder_hidden_state, decoder_cell = self.decoder(labels, encoder_state, encoder_cell)
    # print('logits', logits.shape)
    # print('decoder hidden state', decoder_hidden_state.shape)
    # print('encoder outputs', encoder_outputs.shape)
    # The top hidden state of decoder
    # htl = decoder_hidden_state[-1]

    # numerator = torch.exp(encoder_outputs * htl)
    # denominator = torch.sum(numerator, dim=0)

    # # print('numerator', numerator.shape)
    # # print('denominator', denominator.shape)
    # scores = numerator / denominator
    # # print('score', scores.shape)

    # c = torch.sum(scores * encoder_outputs, dim=0)

    # # print('htl shape', htl.shape)
    # # print('c shape', c.shape)

    # h_attns = torch.tanh(self.W1(logits) + self.W2(c))
    # # print('h_attns', h_attns.shape)
    # return self.W0(h_attns)
    # return logits

# %%
jobs_train, jobs_test = build_datasets()
dataloader_train, dataloader_test = build_dataloaders(jobs_train, jobs_test, train_batch_size=20)

# %%
for d in dataloader_test:
  input, label = d
  # input = torch.transpose(input, 0, -1)
  # label = torch.transpose(label, 0, -1)
  print(input.shape, label.shape)
  model = create_model()
  output = model(input, label)
  print(output.shape)
  break
# Out:
# torch.Size([22, 1]) torch.Size([166, 1])
# torch.Size([166, 1, 503])

# %% [markdown]
# # Todo: Training and testing loops

# %%
QUERY_SOS_INDEX = query_word2idx['<s>']
QUERY_EOS_INDEX = query_word2idx['</s>']
QUERY_PAD_INDEX = query_word2idx['<PAD>']

def padding_mask(idx_tensor):
  return (idx_tensor == QUERY_PAD_INDEX).transpose(0, 1)

loss_fn = torch.nn.CrossEntropyLoss(ignore_index=QUERY_PAD_INDEX)

# %%
def train(model, train_dataloader, num_epochs, device="cuda"):
  for i in range(num_epochs):
    model.train()
    total_loss = 0
    optimizer = torch.optim.Adam(model.parameters())
    for src, tgt in train_dataloader:
        src, tgt = src.to(device), tgt.to(device)
        tgt_input = tgt[:-1, :]

        # print('show src shape:', src.shape)
        # print('show tgt shape:', tgt.shape)
        logits = model(src, tgt_input)

        optimizer.zero_grad()

        tgt_out = tgt[1:, :]
        # print('show logits shape:', logits.shape)
        # print('show labels shape:', tgt_out.shape)
        # raise Exception('lalala')
        loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
        loss.backward()

        optimizer.step()
        total_loss += loss.item()
        # print((f"\rEpoch: {i}, Train loss: {loss:.3f}"), end='')
    # print()
    print((f"Epoch: {i}, Train loss: {total_loss / len(train_dataloader):.3f}"))
  return model

# %%
# This function is obsolete, NEVER USE. 
def evaluate2(model, dataloader, device="cuda"):
    accr = 0
    count = 0
    softmax = nn.Softmax(dim=0)
    for src, tgt in dataloader:
        src, tgt = src.to(device), tgt.to(device)
        tgt_input = tgt[:-1, :]

        logits = model(src, tgt_input)
        tgt_out = tgt[1:, :]
        tgt_padding = padding_mask(tgt_out)
        # loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
        prediction = softmax(logits)
        prediction = torch.argmax(prediction, dim=-1)
        prediction = prediction.squeeze()
        tgt_out = tgt_out.squeeze()
        tgt_padding = tgt_padding.squeeze()
        # print(prediction.shape, tgt_out.shape, tgt_padding.shape)
        for pred, tg, pad in zip(prediction, tgt_out, tgt_padding):
          # print('is pad:', pad)
          if pad.item():
            continue
          if pred == tg:
            accr += 1
          count += 1
        print(f'\rTest Accuracy: {accr / count} ', end='')
    print()
    return accr / count

# This is the correct evaluation function
def evaluate(model, dataloader, device='cuda'):
  accr = 0
  total = 0
  softmax = nn.Softmax(dim=-1)

  for src, tgt in dataloader:
    src, tgt = src.to(device), tgt.to(device)
    tgt_padding_mask = padding_mask(tgt)
    # print('src shape', src.shape)
    encoder_outputs, encoder_state, encoder_cell = model.encoder(src)
    ys = torch.ones(1, 1).fill_(QUERY_SOS_INDEX).type(torch.long).to(device)
    for i in range(queries_max_target_len-1):
      
      # def decode(self, labels, encoder_outputs, encoder_state, encoder_cell):
      out = model.decode(ys, encoder_outputs, encoder_state, encoder_cell).to(device)
      out = out.transpose(0, 1).to(device)
      # out = out[0]
      # print('out:', out.shape)
      prob = softmax(out)
      # print('prob:', prob.shape)
      prob = prob[:, -1]
      # print('prob:', prob)
      _, next_word = torch.max(prob, dim=1)
      # print('next word:', next_word.shape)
      next_word = next_word.item()
      
      ys = torch.cat([ys, torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
      if next_word == QUERY_EOS_INDEX:
          break
    pred = torch.squeeze(ys)
    tgt = torch.squeeze(tgt)
    mask = torch.squeeze(tgt_padding_mask)
    # print('pred:', ys)
    # print('true:', tgt)
    # print('mask:', tgt_padding_mask)
    for p, t, m in zip(pred, tgt, mask):
      if m.item():
        break
      if p == t:
        accr += 1
      total += 1
      print(f'\rEvaluating: per-token accuracy: {accr / total}', end='')
  print()
  return accr / total

# %% [markdown]
# # Run this!
#
# Your outputs should look something like this (not exactly the same numbers, just in a similar ballpark and format).
#
# ```
# Epoch: 1, Train loss: 4.590
# Epoch: 2, Train loss: 1.871
# Epoch: 3, Train loss: 1.424
# ...
# Test Accuracy: 0.5195115804672241
# ```

# %%
def main():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    jobs_train, jobs_test = build_datasets()
    dataloader_train, dataloader_test = build_dataloaders(jobs_train, jobs_test, train_batch_size=20)
    model = create_model()
    model.to(device)
    model = train(model, dataloader_train, num_epochs=25, device=device)
    test_accuracy = evaluate(model, dataloader_test, device=device)
    print(f'Test Accuracy: {test_accuracy}')

main()
# Out:
# Epoch: 0, Train loss: 4.167
# Epoch: 1, Train loss: 2.893
# Epoch: 2, Train loss: 2.318
# Epoch: 3, Train loss: 1.727
# Epoch: 4, Train loss: 1.322
# Epoch: 5, Train loss: 1.094
# Epoch: 6, Train loss: 0.985
# Epoch: 7, Train loss: 0.930
# Epoch: 8, Train loss: 0.873
# Epoch: 9, Train loss: 0.823
# Epoch: 10, Train loss: 0.813
# Epoch: 11, Train loss: 0.781
# Epoch: 12, Train loss: 0.724
# Epoch: 13, Train loss: 0.695
# Epoch: 14, Train loss: 0.670
# Epoch: 15, Train loss: 0.643
# Epoch: 16, Train loss: 0.607
# Epoch: 17, Train loss: 0.621
# Epoch: 18, Train loss: 0.617
# Epoch: 19, Train loss: 0.562
# Epoch: 20, Train loss: 0.543
# Epoch: 21, Train loss: 0.557
# Epoch: 22, Train loss: 0.545
# Epoch: 23, Train loss: 0.528
# Epoch: 24, Train loss: 0.525
# Evaluating: per-token accuracy: 0.5654699049630412
# Test Accuracy: 0.5654699049630412

# %% [markdown]
# Link to this colab:[https://colab.research.google.com/drive/1mj4U9LaUk_BF_8oNaX_tXNj6VqH0p-2v?usp=sharing](https://)
